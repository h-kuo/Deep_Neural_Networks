# %% [markdown]
# <a href="https://colab.research.google.com/github/jeffheaton/t81_558_deep_learning/blob/master/assignments/assignment_yourname_class8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # T81-558: Applications of Deep Neural Networks
# * Instructor: [Jeff Heaton](https://sites.wustl.edu/jeffheaton/), School of Engineering and Applied Science, [Washington University in St. Louis](https://engineering.wustl.edu/Programs/Pages/default.aspx)
# * For more information visit the [class website](https://sites.wustl.edu/jeffheaton/t81-558/).
#
# **Module 8 Assignment: Feature Engineering**
#
# **Student Name: Hao-Tien Kuo**

# %% [markdown]
# # Assignment Instructions
#
# This assignment is similar to assignment 5, except that you must use feature engineering to solve it.  I provide you with a dataset that contains dimensions and the quality of items of specific shapes.  With the values of 'height', 'width', 'depth'. 'shape', and 'quality' you should try to predict the cost of these items.  You should be able to match very close to solution file, if you feature engineer correctly.  To get full credit your average cost should not be more than 50 off from the solution.  The autocorrector will let you know if you are in this range.
#
# You can find all of the needed CSV files here:
#
# * [Shapes - Training](https://data.heatonresearch.com/data/t81-558/datasets/shapes-train.csv)
# * [Shapes - Submit](https://data.heatonresearch.com/data/t81-558/datasets/shapes-test.csv)
#
# Use the training file to train your neural network and submit results for for the data contained in the test/submit file.

# %%
try:
    from google.colab import drive
    drive.mount('/content/drive', force_remount=True)
    COLAB = True
    print("Note: using Google CoLab")
    # %tensorflow_version 2.x
except:
    print("Note: not using Google CoLab")
    COLAB = False
# Out:
# Mounted at /content/drive
# Note: using Google CoLab
# Colab only includes TensorFlow 2.x; %tensorflow_version has no effect.

# %% [markdown]
# # Assignment Submit Function
#
# You will submit the 10 programming assignments electronically.  The following submit function can be used to do this.  My server will perform a basic check of each assignment and let you know if it sees any basic problems.
#
# **It is unlikely that should need to modify this function.**

# %%
import base64
import os
import numpy as np
import pandas as pd
import requests
import PIL
import PIL.Image
import io

# This function submits an assignment.  You can submit an assignment as much as you like, only the final
# submission counts.  The paramaters are as follows:
# data - List of pandas dataframes or images.
# key - Your student key that was emailed to you.
# no - The assignment class number, should be 1 through 1.
# source_file - The full path to your Python or IPYNB file.  This must have "_class1" as part of its name.  
# .             The number must match your assignment number.  For example "_class2" for class assignment #2.
def submit(data,key,no,source_file=None):
    if source_file is None and '__file__' not in globals(): raise Exception('Must specify a filename when a Jupyter notebook.')
    if source_file is None: source_file = __file__
    suffix = '_class{}'.format(no)
    if suffix not in source_file: raise Exception('{} must be part of the filename.'.format(suffix))
    with open(source_file, "rb") as image_file:
        encoded_python = base64.b64encode(image_file.read()).decode('ascii')
    ext = os.path.splitext(source_file)[-1].lower()
    if ext not in ['.ipynb','.py']: raise Exception("Source file is {} must be .py or .ipynb".format(ext))
    payload = []
    for item in data:
        if type(item) is PIL.Image.Image:
            buffered = BytesIO()
            item.save(buffered, format="PNG")
            payload.append({'PNG':base64.b64encode(buffered.getvalue()).decode('ascii')})
        elif type(item) is pd.core.frame.DataFrame:
            payload.append({'CSV':base64.b64encode(item.to_csv(index=False).encode('ascii')).decode("ascii")})
    r= requests.post("https://api.heatonresearch.com/assignment-submit",
        headers={'x-api-key':key}, json={ 'payload': payload,'assignment': no, 'ext':ext, 'py':encoded_python})
    if r.status_code==200:
        print("Success: {}".format(r.text))
    else: print("Failure: {}".format(r.text))

# %% [markdown]
# # Assignment #8 Sample Code
#
# The following code provides a starting point for this assignment.

# %%
import os
import pandas as pd
from scipy.stats import zscore
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation, Dropout
import pandas as pd
import io
import requests
import numpy as np
from sklearn import metrics
from sklearn.model_selection import KFold, train_test_split
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from scipy.stats import zscore

# This is your student key that I emailed to you at the beginnning of the semester.
key = "lhkxWaPDTw1k2isuaX0Gk4X0XN0RcGFX3lEQFj0l" 

# You must also identify your source file.  (modify for your local setup)
file='/content/drive/MyDrive/Colab Notebooks/Deep Neural Networks/assignment_Hao-Tien Kuo_class8.ipynb'  # Google CoLab

# Begin assignment
df_train = pd.read_csv("https://data.heatonresearch.com/data/t81-558/datasets/shapes-train.csv")
df_submit = pd.read_csv("https://data.heatonresearch.com/data/t81-558/datasets/shapes-test.csv")

# %%
df_train.head()
# Out:
#    id  height  width  depth     shape  quality     cost
# 0   1      40     53     89  cylinder       89   200.49
# 1   2      85     35     51       box       37  1175.71
# 2   3      12     19     61       box       23   131.72
# 3   4      29     37     20       box       94    15.83
# 4   5      87     40     22  cylinder       54   340.21

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 7 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   id       10000 non-null  int64
#  1   height   10000 non-null  int64
#  2   width    10000 non-null  int64
#  3   depth    10000 non-null  int64
#  4   shape    10000 non-null  object
#  5   quality  10000 non-null  int64
#  6   cost     10000 non-null  float64
# dtypes: float64(1), int64(5), object(1)
# memory usage: 547.0+ KB

# %%
df_train.describe()
# Out:
#                 id        height         width         depth       quality  \
# count  10000.00000  10000.000000  10000.000000  10000.000000  10000.000000
# mean    5000.50000     49.781000     50.566400     49.825400     50.661500
# std     2886.89568     28.687285     28.633456     28.568968     28.923111
# min        1.00000      1.000000      1.000000      1.000000      1.000000
# 25%     2500.75000     25.000000     26.000000     25.000000     26.000000
# 50%     5000.50000     50.000000     51.000000     49.000000     51.000000
# 75%     7500.25000     74.250000     76.000000     74.000000     76.000000
# max    10000.00000     99.000000     99.000000     99.000000    100.000000
#
#                cost
# count  10000.000000
# mean     554.410241
# std      885.937479
# min        0.000000
# 25%       51.540000
# 50%      205.195000
# 75%      652.015000
# max     8215.950000

# %%
# Generate dummies
df_train = pd.concat([df_train, pd.get_dummies(df_train['shape'])],axis=1)

# Standardize ranges
df_train['height'] = zscore(df_train['height'])
df_train['width'] = zscore(df_train['width'])
df_train['depth'] = zscore(df_train['depth'])
df_train['quality'] = zscore(df_train['quality'])

# Convert to numpy
x_columns = df_train.columns.drop('id').drop('shape').drop('cost')
x = df_train[x_columns].values
y = df_train['cost'].values

# Create train/validation
x_train, x_val, y_train, y_val = train_test_split(x, y, test_size=0.2, random_state=10)

# %%
# Build the neural network
model = Sequential()
model.add(Dense(25, input_dim=x.shape[1], activation='relu')) # Hidden 1
model.add(Dense(10, activation='relu')) # Hidden 2
model.add(Dense(1)) # Output
model.compile(loss='mean_squared_error', metrics=[tf.keras.metrics.RootMeanSquaredError()], optimizer='adam')
monitor = EarlyStopping(monitor='val_loss', min_delta=1e-3, 
                        patience=5, verbose=1, mode='auto', 
                        restore_best_weights=True)
model.fit(x_train,y_train,validation_data=(x_val,y_val),
          callbacks=[monitor],verbose=2,epochs=1000)
# Out:
# Epoch 1/1000
# 250/250 - 3s - loss: 1075066.6250 - root_mean_squared_error: 1036.8542 - val_loss: 1068362.6250 - val_root_mean_squared_error: 1033.6162 - 3s/epoch - 13ms/step
# Epoch 2/1000
# 250/250 - 1s - loss: 912521.9375 - root_mean_squared_error: 955.2601 - val_loss: 752170.4375 - val_root_mean_squared_error: 867.2776 - 554ms/epoch - 2ms/step
# Epoch 3/1000
# 250/250 - 1s - loss: 545400.8125 - root_mean_squared_error: 738.5126 - val_loss: 403682.6875 - val_root_mean_squared_error: 635.3603 - 556ms/epoch - 2ms/step
# Epoch 4/1000
# 250/250 - 1s - loss: 326732.2500 - root_mean_squared_error: 571.6050 - val_loss: 287164.1562 - val_root_mean_squared_error: 535.8770 - 506ms/epoch - 2ms/step
# Epoch 5/1000
# 250/250 - 0s - loss: 260773.2812 - root_mean_squared_error: 510.6596 - val_loss: 244296.8125 - val_root_mean_squared_error: 494.2639 - 499ms/epoch - 2ms/step
# Epoch 6/1000
# 250/250 - 1s - loss: 226682.7031 - root_mean_squared_error: 476.1121 - val_loss: 214591.8594 - val_root_mean_squared_error: 463.2406 - 506ms/epoch - 2ms/step
# Epoch 7/1000
# 250/250 - 0s - loss: 201910.6875 - root_mean_squared_error: 449.3447 - val_loss: 193172.2656 - val_root_mean_squared_error: 439.5137 - 495ms/epoch - 2ms/step
# Epoch 8/1000
# 250/250 - 1s - loss: 183139.8438 - root_mean_squared_error: 427.9484 - val_loss: 176069.5781 - val_root_mean_squared_error: 419.6064 - 502ms/epoch - 2ms/step
# Epoch 9/1000
# 250/250 - 1s - loss: 168367.6562 - root_mean_squared_error: 410.3263 - val_loss: 162659.1094 - val_root_mean_squared_error: 403.3102 - 503ms/epoch - 2ms/step
# Epoch 10/1000
# 250/250 - 1s - loss: 156470.4844 - root_mean_squared_error: 395.5635 - val_loss: 151536.8906 - val_root_mean_squared_error: 389.2774 - 516ms/epoch - 2ms/step
# Epoch 11/1000
# 250/250 - 1s - loss: 146706.7188 - root_mean_squared_error: 383.0231 - val_loss: 142764.8906 - val_root_mean_squared_error: 377.8424 - 503ms/epoch - 2ms/step
# Epoch 12/1000
# 250/250 - 1s - loss: 138731.5156 - root_mean_squared_error: 372.4668 - val_loss: 135094.9219 - val_root_mean_squared_error: 367.5526 - 545ms/epoch - 2ms/step
# Epoch 13/1000
# 250/250 - 1s - loss: 131911.2500 - root_mean_squared_error: 363.1959 - val_loss: 128643.8906 - val_root_mean_squared_error: 358.6696 - 507ms/epoch - 2ms/step
# Epoch 14/1000
# 250/250 - 1s - loss: 126031.7578 - root_mean_squared_error: 355.0095 - val_loss: 123109.5156 - val_root_mean_squared_error: 350.8697 - 569ms/epoch - 2ms/step
# Epoch 15/1000
# 250/250 - 0s - loss: 121058.9141 - root_mean_squared_error: 347.9352 - val_loss: 118452.0156 - val_root_mean_squared_error: 344.1686 - 497ms/epoch - 2ms/step
# Epoch 16/1000
# 250/250 - 1s - loss: 116513.1953 - root_mean_squared_error: 341.3403 - val_loss: 114405.6797 - val_root_mean_squared_error: 338.2391 - 557ms/epoch - 2ms/step
# Epoch 17/1000
# 250/250 - 1s - loss: 112484.9688 - root_mean_squared_error: 335.3878 - val_loss: 110511.3984 - val_root_mean_squared_error: 332.4326 - 547ms/epoch - 2ms/step
# Epoch 18/1000
# 250/250 - 1s - loss: 108963.7578 - root_mean_squared_error: 330.0966 - val_loss: 107074.0391 - val_root_mean_squared_error: 327.2217 - 511ms/epoch - 2ms/step
# Epoch 19/1000
# 250/250 - 1s - loss: 105595.2891 - root_mean_squared_error: 324.9543 - val_loss: 104140.4531 - val_root_mean_squared_error: 322.7080 - 503ms/epoch - 2ms/step
# Epoch 20/1000
# 250/250 - 1s - loss: 102472.2188 - root_mean_squared_error: 320.1128 - val_loss: 100851.7656 - val_root_mean_squared_error: 317.5717 - 510ms/epoch - 2ms/step
# Epoch 21/1000
# 250/250 - 0s - loss: 99424.7266 - root_mean_squared_error: 315.3169 - val_loss: 98095.4219 - val_root_mean_squared_error: 313.2019 - 499ms/epoch - 2ms/step
# Epoch 22/1000
# 250/250 - 1s - loss: 96565.7031 - root_mean_squared_error: 310.7502 - val_loss: 95507.7188 - val_root_mean_squared_error: 309.0432 - 508ms/epoch - 2ms/step
# Epoch 23/1000
# 250/250 - 0s - loss: 93786.5938 - root_mean_squared_error: 306.2460 - val_loss: 92618.7578 - val_root_mean_squared_error: 304.3333 - 500ms/epoch - 2ms/step
# Epoch 24/1000
# 250/250 - 1s - loss: 90847.2812 - root_mean_squared_error: 301.4088 - val_loss: 90123.1797 - val_root_mean_squared_error: 300.2052 - 514ms/epoch - 2ms/step
# Epoch 25/1000
# 250/250 - 1s - loss: 88151.9219 - root_mean_squared_error: 296.9039 - val_loss: 86984.0469 - val_root_mean_squared_error: 294.9306 - 515ms/epoch - 2ms/step
# Epoch 26/1000
# 250/250 - 1s - loss: 85367.6016 - root_mean_squared_error: 292.1773 - val_loss: 84332.2891 - val_root_mean_squared_error: 290.4002 - 560ms/epoch - 2ms/step
# Epoch 27/1000
# 250/250 - 0s - loss: 82628.9844 - root_mean_squared_error: 287.4526 - val_loss: 81795.6250 - val_root_mean_squared_error: 285.9994 - 490ms/epoch - 2ms/step
# Epoch 28/1000
# 250/250 - 1s - loss: 79967.2578 - root_mean_squared_error: 282.7848 - val_loss: 79224.4688 - val_root_mean_squared_error: 281.4684 - 563ms/epoch - 2ms/step
# Epoch 29/1000
# 250/250 - 1s - loss: 77534.4922 - root_mean_squared_error: 278.4502 - val_loss: 76832.7500 - val_root_mean_squared_error: 277.1872 - 769ms/epoch - 3ms/step
# Epoch 30/1000
# 250/250 - 1s - loss: 75017.5703 - root_mean_squared_error: 273.8933 - val_loss: 74555.1797 - val_root_mean_squared_error: 273.0479 - 567ms/epoch - 2ms/step
# Epoch 31/1000
# 250/250 - 1s - loss: 72735.6172 - root_mean_squared_error: 269.6954 - val_loss: 72399.3906 - val_root_mean_squared_error: 269.0714 - 816ms/epoch - 3ms/step
# Epoch 32/1000
# 250/250 - 1s - loss: 70620.9219 - root_mean_squared_error: 265.7460 - val_loss: 70343.1250 - val_root_mean_squared_error: 265.2228 - 812ms/epoch - 3ms/step
# Epoch 33/1000
# 250/250 - 1s - loss: 68547.3203 - root_mean_squared_error: 261.8154 - val_loss: 68423.5859 - val_root_mean_squared_error: 261.5790 - 500ms/epoch - 2ms/step
# Epoch 34/1000
# 250/250 - 1s - loss: 66513.9219 - root_mean_squared_error: 257.9029 - val_loss: 66624.3906 - val_root_mean_squared_error: 258.1170 - 510ms/epoch - 2ms/step
# Epoch 35/1000
# 250/250 - 1s - loss: 64737.9414 - root_mean_squared_error: 254.4365 - val_loss: 64891.2461 - val_root_mean_squared_error: 254.7376 - 543ms/epoch - 2ms/step
# Epoch 36/1000
# 250/250 - 1s - loss: 62984.8555 - root_mean_squared_error: 250.9678 - val_loss: 63265.5859 - val_root_mean_squared_error: 251.5265 - 514ms/epoch - 2ms/step
# Epoch 37/1000
# 250/250 - 1s - loss: 61236.5586 - root_mean_squared_error: 247.4602 - val_loss: 61859.5625 - val_root_mean_squared_error: 248.7158 - 504ms/epoch - 2ms/step
# Epoch 38/1000
# 250/250 - 1s - loss: 59705.1719 - root_mean_squared_error: 244.3464 - val_loss: 60566.2695 - val_root_mean_squared_error: 246.1021 - 518ms/epoch - 2ms/step
# Epoch 39/1000
# 250/250 - 1s - loss: 58262.0781 - root_mean_squared_error: 241.3754 - val_loss: 58728.4453 - val_root_mean_squared_error: 242.3395 - 526ms/epoch - 2ms/step
# Epoch 40/1000
# 250/250 - 1s - loss: 56763.7539 - root_mean_squared_error: 238.2514 - val_loss: 57251.5703 - val_root_mean_squared_error: 239.2730 - 564ms/epoch - 2ms/step
# Epoch 41/1000
# 250/250 - 0s - loss: 55358.6484 - root_mean_squared_error: 235.2842 - val_loss: 56034.0664 - val_root_mean_squared_error: 236.7152 - 499ms/epoch - 2ms/step
# Epoch 42/1000
# 250/250 - 1s - loss: 54096.2656 - root_mean_squared_error: 232.5860 - val_loss: 54928.3945 - val_root_mean_squared_error: 234.3681 - 545ms/epoch - 2ms/step
# Epoch 43/1000
# 250/250 - 1s - loss: 52815.0625 - root_mean_squared_error: 229.8153 - val_loss: 53549.5781 - val_root_mean_squared_error: 231.4078 - 515ms/epoch - 2ms/step
# Epoch 44/1000
# 250/250 - 1s - loss: 51593.8438 - root_mean_squared_error: 227.1428 - val_loss: 52334.7930 - val_root_mean_squared_error: 228.7680 - 505ms/epoch - 2ms/step
# Epoch 45/1000
# 250/250 - 1s - loss: 50485.1484 - root_mean_squared_error: 224.6890 - val_loss: 51233.8867 - val_root_mean_squared_error: 226.3490 - 554ms/epoch - 2ms/step
# Epoch 46/1000
# 250/250 - 1s - loss: 49190.5156 - root_mean_squared_error: 221.7894 - val_loss: 50176.8477 - val_root_mean_squared_error: 224.0019 - 548ms/epoch - 2ms/step
# Epoch 47/1000
# 250/250 - 1s - loss: 48083.1289 - root_mean_squared_error: 219.2787 - val_loss: 49417.3477 - val_root_mean_squared_error: 222.3001 - 525ms/epoch - 2ms/step
# Epoch 48/1000
# 250/250 - 1s - loss: 47107.0234 - root_mean_squared_error: 217.0415 - val_loss: 49226.1133 - val_root_mean_squared_error: 221.8696 - 545ms/epoch - 2ms/step
# Epoch 49/1000
# 250/250 - 1s - loss: 46149.2422 - root_mean_squared_error: 214.8237 - val_loss: 47568.9805 - val_root_mean_squared_error: 218.1031 - 533ms/epoch - 2ms/step
# Epoch 50/1000
# 250/250 - 1s - loss: 45209.0391 - root_mean_squared_error: 212.6242 - val_loss: 46499.5117 - val_root_mean_squared_error: 215.6375 - 543ms/epoch - 2ms/step
# Epoch 51/1000
# 250/250 - 1s - loss: 44322.3633 - root_mean_squared_error: 210.5288 - val_loss: 45680.5352 - val_root_mean_squared_error: 213.7300 - 510ms/epoch - 2ms/step
# Epoch 52/1000
# 250/250 - 1s - loss: 43554.6328 - root_mean_squared_error: 208.6975 - val_loss: 44947.9805 - val_root_mean_squared_error: 212.0094 - 508ms/epoch - 2ms/step
# Epoch 53/1000
# 250/250 - 1s - loss: 42811.1484 - root_mean_squared_error: 206.9086 - val_loss: 44549.4258 - val_root_mean_squared_error: 211.0674 - 569ms/epoch - 2ms/step
# Epoch 54/1000
# 250/250 - 0s - loss: 42061.0117 - root_mean_squared_error: 205.0878 - val_loss: 43626.4258 - val_root_mean_squared_error: 208.8694 - 492ms/epoch - 2ms/step
# Epoch 55/1000
# 250/250 - 1s - loss: 41471.5469 - root_mean_squared_error: 203.6456 - val_loss: 43482.0508 - val_root_mean_squared_error: 208.5235 - 539ms/epoch - 2ms/step
# Epoch 56/1000
# 250/250 - 1s - loss: 40918.3164 - root_mean_squared_error: 202.2828 - val_loss: 42646.2109 - val_root_mean_squared_error: 206.5096 - 590ms/epoch - 2ms/step
# Epoch 57/1000
# 250/250 - 1s - loss: 40390.7695 - root_mean_squared_error: 200.9745 - val_loss: 42066.4766 - val_root_mean_squared_error: 205.1011 - 858ms/epoch - 3ms/step
# Epoch 58/1000
# 250/250 - 1s - loss: 39789.2891 - root_mean_squared_error: 199.4725 - val_loss: 42010.1094 - val_root_mean_squared_error: 204.9637 - 744ms/epoch - 3ms/step
# Epoch 59/1000
# 250/250 - 1s - loss: 39423.4062 - root_mean_squared_error: 198.5533 - val_loss: 41332.1602 - val_root_mean_squared_error: 203.3031 - 754ms/epoch - 3ms/step
# Epoch 60/1000
# 250/250 - 1s - loss: 39000.5898 - root_mean_squared_error: 197.4857 - val_loss: 41199.3281 - val_root_mean_squared_error: 202.9762 - 715ms/epoch - 3ms/step
# Epoch 61/1000
# 250/250 - 1s - loss: 38611.9297 - root_mean_squared_error: 196.4992 - val_loss: 41011.6016 - val_root_mean_squared_error: 202.5132 - 516ms/epoch - 2ms/step
# Epoch 62/1000
# 250/250 - 1s - loss: 38349.8555 - root_mean_squared_error: 195.8312 - val_loss: 40393.1953 - val_root_mean_squared_error: 200.9806 - 553ms/epoch - 2ms/step
# Epoch 63/1000
# 250/250 - 1s - loss: 37996.3750 - root_mean_squared_error: 194.9266 - val_loss: 40052.4727 - val_root_mean_squared_error: 200.1311 - 502ms/epoch - 2ms/step
# Epoch 64/1000
# 250/250 - 1s - loss: 37735.8516 - root_mean_squared_error: 194.2572 - val_loss: 39899.8203 - val_root_mean_squared_error: 199.7494 - 514ms/epoch - 2ms/step
# Epoch 65/1000
# 250/250 - 1s - loss: 37557.8750 - root_mean_squared_error: 193.7985 - val_loss: 40047.5703 - val_root_mean_squared_error: 200.1189 - 516ms/epoch - 2ms/step
# Epoch 66/1000
# 250/250 - 1s - loss: 37233.3438 - root_mean_squared_error: 192.9594 - val_loss: 39655.9727 - val_root_mean_squared_error: 199.1381 - 573ms/epoch - 2ms/step
# Epoch 67/1000
# 250/250 - 1s - loss: 37035.1250 - root_mean_squared_error: 192.4451 - val_loss: 39444.0547 - val_root_mean_squared_error: 198.6053 - 569ms/epoch - 2ms/step
# Epoch 68/1000
# 250/250 - 1s - loss: 36815.8477 - root_mean_squared_error: 191.8746 - val_loss: 39143.6562 - val_root_mean_squared_error: 197.8475 - 777ms/epoch - 3ms/step
# Epoch 69/1000
# 250/250 - 1s - loss: 36662.6289 - root_mean_squared_error: 191.4749 - val_loss: 38920.4570 - val_root_mean_squared_error: 197.2827 - 756ms/epoch - 3ms/step
# Epoch 70/1000
# 250/250 - 1s - loss: 36510.8164 - root_mean_squared_error: 191.0780 - val_loss: 39167.5234 - val_root_mean_squared_error: 197.9079 - 749ms/epoch - 3ms/step
# Epoch 71/1000
# 250/250 - 1s - loss: 36331.0859 - root_mean_squared_error: 190.6071 - val_loss: 38925.6680 - val_root_mean_squared_error: 197.2959 - 752ms/epoch - 3ms/step
# Epoch 72/1000
# 250/250 - 1s - loss: 36167.5977 - root_mean_squared_error: 190.1778 - val_loss: 38756.3906 - val_root_mean_squared_error: 196.8664 - 606ms/epoch - 2ms/step
# Epoch 73/1000
# 250/250 - 1s - loss: 36124.9102 - root_mean_squared_error: 190.0655 - val_loss: 38440.8359 - val_root_mean_squared_error: 196.0633 - 508ms/epoch - 2ms/step
# Epoch 74/1000
# 250/250 - 1s - loss: 35951.6992 - root_mean_squared_error: 189.6093 - val_loss: 38751.4883 - val_root_mean_squared_error: 196.8540 - 511ms/epoch - 2ms/step
# Epoch 75/1000
# 250/250 - 1s - loss: 35817.8984 - root_mean_squared_error: 189.2562 - val_loss: 38239.4141 - val_root_mean_squared_error: 195.5490 - 552ms/epoch - 2ms/step
# Epoch 76/1000
# 250/250 - 1s - loss: 35694.3516 - root_mean_squared_error: 188.9295 - val_loss: 38193.9102 - val_root_mean_squared_error: 195.4326 - 561ms/epoch - 2ms/step
# Epoch 77/1000
# 250/250 - 1s - loss: 35621.6641 - root_mean_squared_error: 188.7370 - val_loss: 38042.4258 - val_root_mean_squared_error: 195.0447 - 514ms/epoch - 2ms/step
# Epoch 78/1000
# 250/250 - 1s - loss: 35481.1133 - root_mean_squared_error: 188.3643 - val_loss: 37999.8789 - val_root_mean_squared_error: 194.9356 - 525ms/epoch - 2ms/step
# Epoch 79/1000
# 250/250 - 1s - loss: 35449.8984 - root_mean_squared_error: 188.2814 - val_loss: 38069.6641 - val_root_mean_squared_error: 195.1145 - 522ms/epoch - 2ms/step
# Epoch 80/1000
# 250/250 - 1s - loss: 35394.6211 - root_mean_squared_error: 188.1346 - val_loss: 37763.9141 - val_root_mean_squared_error: 194.3294 - 574ms/epoch - 2ms/step
# Epoch 81/1000
# 250/250 - 1s - loss: 35314.3398 - root_mean_squared_error: 187.9211 - val_loss: 37721.3633 - val_root_mean_squared_error: 194.2199 - 548ms/epoch - 2ms/step
# Epoch 82/1000
# 250/250 - 1s - loss: 35173.6016 - root_mean_squared_error: 187.5463 - val_loss: 37810.1836 - val_root_mean_squared_error: 194.4484 - 561ms/epoch - 2ms/step
# Epoch 83/1000
# 250/250 - 1s - loss: 35131.1562 - root_mean_squared_error: 187.4331 - val_loss: 37402.3945 - val_root_mean_squared_error: 193.3970 - 509ms/epoch - 2ms/step
# Epoch 84/1000
# 250/250 - 1s - loss: 35032.0977 - root_mean_squared_error: 187.1686 - val_loss: 37372.1328 - val_root_mean_squared_error: 193.3187 - 525ms/epoch - 2ms/step
# Epoch 85/1000
# 250/250 - 1s - loss: 34984.6992 - root_mean_squared_error: 187.0420 - val_loss: 37538.7656 - val_root_mean_squared_error: 193.7492 - 511ms/epoch - 2ms/step
# Epoch 86/1000
# 250/250 - 1s - loss: 34868.3594 - root_mean_squared_error: 186.7307 - val_loss: 37438.7109 - val_root_mean_squared_error: 193.4908 - 558ms/epoch - 2ms/step
# Epoch 87/1000
# 250/250 - 0s - loss: 34834.6484 - root_mean_squared_error: 186.6404 - val_loss: 37140.3867 - val_root_mean_squared_error: 192.7184 - 491ms/epoch - 2ms/step
# Epoch 88/1000
# 250/250 - 1s - loss: 34785.1133 - root_mean_squared_error: 186.5077 - val_loss: 37091.3438 - val_root_mean_squared_error: 192.5911 - 550ms/epoch - 2ms/step
# Epoch 89/1000
# 250/250 - 1s - loss: 34711.5469 - root_mean_squared_error: 186.3103 - val_loss: 37239.3047 - val_root_mean_squared_error: 192.9749 - 557ms/epoch - 2ms/step
# Epoch 90/1000
# 250/250 - 0s - loss: 34664.6992 - root_mean_squared_error: 186.1846 - val_loss: 37094.0977 - val_root_mean_squared_error: 192.5983 - 496ms/epoch - 2ms/step
# Epoch 91/1000
# 250/250 - 1s - loss: 34599.4336 - root_mean_squared_error: 186.0092 - val_loss: 36927.5664 - val_root_mean_squared_error: 192.1655 - 510ms/epoch - 2ms/step
# Epoch 92/1000
# 250/250 - 1s - loss: 34521.8047 - root_mean_squared_error: 185.8004 - val_loss: 36891.5078 - val_root_mean_squared_error: 192.0716 - 572ms/epoch - 2ms/step
# Epoch 93/1000
# 250/250 - 1s - loss: 34511.5117 - root_mean_squared_error: 185.7727 - val_loss: 36764.7656 - val_root_mean_squared_error: 191.7414 - 579ms/epoch - 2ms/step
# Epoch 94/1000
# 250/250 - 0s - loss: 34464.1367 - root_mean_squared_error: 185.6452 - val_loss: 37725.7539 - val_root_mean_squared_error: 194.2312 - 494ms/epoch - 2ms/step
# Epoch 95/1000
# 250/250 - 1s - loss: 34370.2891 - root_mean_squared_error: 185.3923 - val_loss: 36788.4570 - val_root_mean_squared_error: 191.8032 - 510ms/epoch - 2ms/step
# Epoch 96/1000
# 250/250 - 1s - loss: 34312.9766 - root_mean_squared_error: 185.2376 - val_loss: 36748.6094 - val_root_mean_squared_error: 191.6993 - 503ms/epoch - 2ms/step
# Epoch 97/1000
# 250/250 - 1s - loss: 34271.3633 - root_mean_squared_error: 185.1253 - val_loss: 36792.6836 - val_root_mean_squared_error: 191.8142 - 515ms/epoch - 2ms/step
# Epoch 98/1000
# 250/250 - 1s - loss: 34262.9102 - root_mean_squared_error: 185.1024 - val_loss: 36563.6758 - val_root_mean_squared_error: 191.2163 - 545ms/epoch - 2ms/step
# Epoch 99/1000
# 250/250 - 1s - loss: 34146.6523 - root_mean_squared_error: 184.7881 - val_loss: 36883.5078 - val_root_mean_squared_error: 192.0508 - 516ms/epoch - 2ms/step
# Epoch 100/1000
# 250/250 - 1s - loss: 34142.6641 - root_mean_squared_error: 184.7773 - val_loss: 36869.7422 - val_root_mean_squared_error: 192.0150 - 500ms/epoch - 2ms/step
# Epoch 101/1000
# 250/250 - 1s - loss: 34125.4297 - root_mean_squared_error: 184.7307 - val_loss: 36482.9062 - val_root_mean_squared_error: 191.0050 - 556ms/epoch - 2ms/step
# Epoch 102/1000
# 250/250 - 0s - loss: 34062.7891 - root_mean_squared_error: 184.5611 - val_loss: 36445.4453 - val_root_mean_squared_error: 190.9069 - 495ms/epoch - 2ms/step
# Epoch 103/1000
# 250/250 - 1s - loss: 34057.0234 - root_mean_squared_error: 184.5455 - val_loss: 36467.3281 - val_root_mean_squared_error: 190.9642 - 518ms/epoch - 2ms/step
# Epoch 104/1000
# 250/250 - 1s - loss: 33974.7539 - root_mean_squared_error: 184.3224 - val_loss: 36705.5469 - val_root_mean_squared_error: 191.5869 - 505ms/epoch - 2ms/step
# Epoch 105/1000
# 250/250 - 1s - loss: 33941.9102 - root_mean_squared_error: 184.2333 - val_loss: 36345.3672 - val_root_mean_squared_error: 190.6446 - 521ms/epoch - 2ms/step
# Epoch 106/1000
# 250/250 - 1s - loss: 33954.4414 - root_mean_squared_error: 184.2673 - val_loss: 36448.4414 - val_root_mean_squared_error: 190.9147 - 559ms/epoch - 2ms/step
# Epoch 107/1000
# 250/250 - 1s - loss: 33871.5039 - root_mean_squared_error: 184.0421 - val_loss: 36375.4883 - val_root_mean_squared_error: 190.7236 - 526ms/epoch - 2ms/step
# Epoch 108/1000
# 250/250 - 1s - loss: 33848.7383 - root_mean_squared_error: 183.9803 - val_loss: 36439.9688 - val_root_mean_squared_error: 190.8925 - 551ms/epoch - 2ms/step
# Epoch 109/1000
# 250/250 - 0s - loss: 33799.7695 - root_mean_squared_error: 183.8471 - val_loss: 36222.5352 - val_root_mean_squared_error: 190.3222 - 495ms/epoch - 2ms/step
# Epoch 110/1000
# 250/250 - 1s - loss: 33784.5469 - root_mean_squared_error: 183.8057 - val_loss: 36222.7852 - val_root_mean_squared_error: 190.3228 - 513ms/epoch - 2ms/step
# Epoch 111/1000
# 250/250 - 0s - loss: 33745.6133 - root_mean_squared_error: 183.6998 - val_loss: 36079.8047 - val_root_mean_squared_error: 189.9468 - 500ms/epoch - 2ms/step
# Epoch 112/1000
# 250/250 - 1s - loss: 33705.6445 - root_mean_squared_error: 183.5910 - val_loss: 36043.8516 - val_root_mean_squared_error: 189.8522 - 556ms/epoch - 2ms/step
# Epoch 113/1000
# 250/250 - 1s - loss: 33688.0469 - root_mean_squared_error: 183.5430 - val_loss: 36054.8359 - val_root_mean_squared_error: 189.8811 - 549ms/epoch - 2ms/step
# Epoch 114/1000
# 250/250 - 1s - loss: 33620.7734 - root_mean_squared_error: 183.3597 - val_loss: 36234.6797 - val_root_mean_squared_error: 190.3541 - 555ms/epoch - 2ms/step
# Epoch 115/1000
# 250/250 - 1s - loss: 33589.8906 - root_mean_squared_error: 183.2755 - val_loss: 36063.1953 - val_root_mean_squared_error: 189.9031 - 552ms/epoch - 2ms/step
# Epoch 116/1000
# 250/250 - 1s - loss: 33590.9922 - root_mean_squared_error: 183.2785 - val_loss: 36385.0117 - val_root_mean_squared_error: 190.7486 - 507ms/epoch - 2ms/step
# Epoch 117/1000
# 250/250 - 1s - loss: 33544.9414 - root_mean_squared_error: 183.1528 - val_loss: 35952.7734 - val_root_mean_squared_error: 189.6122 - 552ms/epoch - 2ms/step
# Epoch 118/1000
# 250/250 - 1s - loss: 33512.7891 - root_mean_squared_error: 183.0650 - val_loss: 35855.1172 - val_root_mean_squared_error: 189.3545 - 564ms/epoch - 2ms/step
# Epoch 119/1000
# 250/250 - 1s - loss: 33510.3672 - root_mean_squared_error: 183.0584 - val_loss: 35917.5352 - val_root_mean_squared_error: 189.5192 - 550ms/epoch - 2ms/step
# Epoch 120/1000
# 250/250 - 1s - loss: 33444.8047 - root_mean_squared_error: 182.8792 - val_loss: 35886.1602 - val_root_mean_squared_error: 189.4364 - 510ms/epoch - 2ms/step
# Epoch 121/1000
# 250/250 - 1s - loss: 33394.0703 - root_mean_squared_error: 182.7404 - val_loss: 35789.9062 - val_root_mean_squared_error: 189.1822 - 559ms/epoch - 2ms/step
# Epoch 122/1000
# 250/250 - 1s - loss: 33381.5508 - root_mean_squared_error: 182.7062 - val_loss: 35956.8086 - val_root_mean_squared_error: 189.6228 - 526ms/epoch - 2ms/step
# Epoch 123/1000
# 250/250 - 1s - loss: 33305.9648 - root_mean_squared_error: 182.4992 - val_loss: 35715.4062 - val_root_mean_squared_error: 188.9852 - 524ms/epoch - 2ms/step
# Epoch 124/1000
# 250/250 - 1s - loss: 33346.2109 - root_mean_squared_error: 182.6095 - val_loss: 35857.1016 - val_root_mean_squared_error: 189.3597 - 526ms/epoch - 2ms/step
# Epoch 125/1000
# 250/250 - 1s - loss: 33271.1328 - root_mean_squared_error: 182.4038 - val_loss: 36089.6758 - val_root_mean_squared_error: 189.9728 - 560ms/epoch - 2ms/step
# Epoch 126/1000
# 250/250 - 1s - loss: 33319.0859 - root_mean_squared_error: 182.5352 - val_loss: 35778.5977 - val_root_mean_squared_error: 189.1523 - 516ms/epoch - 2ms/step
# Epoch 127/1000
# 250/250 - 1s - loss: 33192.3281 - root_mean_squared_error: 182.1876 - val_loss: 35640.6953 - val_root_mean_squared_error: 188.7874 - 515ms/epoch - 2ms/step
# Epoch 128/1000
# 250/250 - 1s - loss: 33232.3984 - root_mean_squared_error: 182.2976 - val_loss: 36428.1758 - val_root_mean_squared_error: 190.8617 - 505ms/epoch - 2ms/step
# Epoch 129/1000
# 250/250 - 1s - loss: 33173.2539 - root_mean_squared_error: 182.1353 - val_loss: 36076.2383 - val_root_mean_squared_error: 189.9375 - 515ms/epoch - 2ms/step
# Epoch 130/1000
# 250/250 - 1s - loss: 33154.4023 - root_mean_squared_error: 182.0835 - val_loss: 35611.3008 - val_root_mean_squared_error: 188.7096 - 505ms/epoch - 2ms/step
# Epoch 131/1000
# 250/250 - 1s - loss: 33136.0430 - root_mean_squared_error: 182.0331 - val_loss: 35687.1914 - val_root_mean_squared_error: 188.9105 - 512ms/epoch - 2ms/step
# Epoch 132/1000
# 250/250 - 1s - loss: 33142.1875 - root_mean_squared_error: 182.0500 - val_loss: 35628.5742 - val_root_mean_squared_error: 188.7553 - 544ms/epoch - 2ms/step
# Epoch 133/1000
# 250/250 - 1s - loss: 33132.3438 - root_mean_squared_error: 182.0229 - val_loss: 35523.5000 - val_root_mean_squared_error: 188.4768 - 506ms/epoch - 2ms/step
# Epoch 134/1000
# 250/250 - 1s - loss: 33060.8984 - root_mean_squared_error: 181.8266 - val_loss: 35505.2656 - val_root_mean_squared_error: 188.4284 - 549ms/epoch - 2ms/step
# Epoch 135/1000
# 250/250 - 1s - loss: 33115.9609 - root_mean_squared_error: 181.9779 - val_loss: 35708.8633 - val_root_mean_squared_error: 188.9679 - 560ms/epoch - 2ms/step
# Epoch 136/1000
# 250/250 - 1s - loss: 33104.0703 - root_mean_squared_error: 181.9452 - val_loss: 35502.7773 - val_root_mean_squared_error: 188.4218 - 512ms/epoch - 2ms/step
# Epoch 137/1000
# 250/250 - 1s - loss: 33044.8281 - root_mean_squared_error: 181.7824 - val_loss: 35546.7969 - val_root_mean_squared_error: 188.5386 - 568ms/epoch - 2ms/step
# Epoch 138/1000
# 250/250 - 1s - loss: 33023.7344 - root_mean_squared_error: 181.7243 - val_loss: 35706.8906 - val_root_mean_squared_error: 188.9627 - 531ms/epoch - 2ms/step
# Epoch 139/1000
# 250/250 - 1s - loss: 33005.7539 - root_mean_squared_error: 181.6749 - val_loss: 36001.9336 - val_root_mean_squared_error: 189.7417 - 544ms/epoch - 2ms/step
# Epoch 140/1000
# 250/250 - 1s - loss: 33009.8125 - root_mean_squared_error: 181.6860 - val_loss: 35669.5391 - val_root_mean_squared_error: 188.8638 - 510ms/epoch - 2ms/step
# Epoch 141/1000
# 250/250 - 1s - loss: 32974.1602 - root_mean_squared_error: 181.5879 - val_loss: 35462.7031 - val_root_mean_squared_error: 188.3154 - 567ms/epoch - 2ms/step
# Epoch 142/1000
# 250/250 - 1s - loss: 32913.4922 - root_mean_squared_error: 181.4208 - val_loss: 35396.0938 - val_root_mean_squared_error: 188.1385 - 554ms/epoch - 2ms/step
# Epoch 143/1000
# 250/250 - 1s - loss: 32897.1641 - root_mean_squared_error: 181.3757 - val_loss: 35441.4453 - val_root_mean_squared_error: 188.2590 - 533ms/epoch - 2ms/step
# Epoch 144/1000
# 250/250 - 1s - loss: 32906.9414 - root_mean_squared_error: 181.4027 - val_loss: 35397.4805 - val_root_mean_squared_error: 188.1422 - 508ms/epoch - 2ms/step
# Epoch 145/1000
# 250/250 - 1s - loss: 32898.7305 - root_mean_squared_error: 181.3801 - val_loss: 35598.1289 - val_root_mean_squared_error: 188.6747 - 502ms/epoch - 2ms/step
# Epoch 146/1000
# 250/250 - 1s - loss: 32905.1289 - root_mean_squared_error: 181.3977 - val_loss: 35380.1406 - val_root_mean_squared_error: 188.0961 - 508ms/epoch - 2ms/step
# Epoch 147/1000
# 250/250 - 1s - loss: 32842.3203 - root_mean_squared_error: 181.2245 - val_loss: 35344.1914 - val_root_mean_squared_error: 188.0005 - 549ms/epoch - 2ms/step
# Epoch 148/1000
# 250/250 - 1s - loss: 32858.8828 - root_mean_squared_error: 181.2702 - val_loss: 35529.6406 - val_root_mean_squared_error: 188.4931 - 514ms/epoch - 2ms/step
# Epoch 149/1000
# 250/250 - 1s - loss: 32855.0781 - root_mean_squared_error: 181.2597 - val_loss: 35371.3086 - val_root_mean_squared_error: 188.0726 - 530ms/epoch - 2ms/step
# Epoch 150/1000
# 250/250 - 0s - loss: 32834.3242 - root_mean_squared_error: 181.2024 - val_loss: 35366.3086 - val_root_mean_squared_error: 188.0593 - 496ms/epoch - 2ms/step
# Epoch 151/1000
# 250/250 - 0s - loss: 32832.2812 - root_mean_squared_error: 181.1968 - val_loss: 35393.5625 - val_root_mean_squared_error: 188.1318 - 494ms/epoch - 2ms/step
# Epoch 152/1000
# 250/250 - 0s - loss: 32786.9531 - root_mean_squared_error: 181.0717 - val_loss: 35327.7773 - val_root_mean_squared_error: 187.9568 - 497ms/epoch - 2ms/step
# Epoch 153/1000
# 250/250 - 1s - loss: 32843.1250 - root_mean_squared_error: 181.2267 - val_loss: 35336.3242 - val_root_mean_squared_error: 187.9796 - 540ms/epoch - 2ms/step
# Epoch 154/1000
# 250/250 - 1s - loss: 32753.6836 - root_mean_squared_error: 180.9798 - val_loss: 35640.0703 - val_root_mean_squared_error: 188.7858 - 552ms/epoch - 2ms/step
# Epoch 155/1000
# 250/250 - 0s - loss: 32818.2695 - root_mean_squared_error: 181.1581 - val_loss: 35487.6250 - val_root_mean_squared_error: 188.3816 - 496ms/epoch - 2ms/step
# Epoch 156/1000
# 250/250 - 0s - loss: 32768.1016 - root_mean_squared_error: 181.0196 - val_loss: 35307.3047 - val_root_mean_squared_error: 187.9024 - 495ms/epoch - 2ms/step
# Epoch 157/1000
# 250/250 - 1s - loss: 32749.0020 - root_mean_squared_error: 180.9669 - val_loss: 35260.1836 - val_root_mean_squared_error: 187.7769 - 511ms/epoch - 2ms/step
# Epoch 158/1000
# 250/250 - 1s - loss: 32757.4531 - root_mean_squared_error: 180.9902 - val_loss: 35395.8906 - val_root_mean_squared_error: 188.1380 - 523ms/epoch - 2ms/step
# Epoch 159/1000
# 250/250 - 1s - loss: 32788.7266 - root_mean_squared_error: 181.0766 - val_loss: 35258.7227 - val_root_mean_squared_error: 187.7731 - 552ms/epoch - 2ms/step
# Epoch 160/1000
# 250/250 - 1s - loss: 32727.1719 - root_mean_squared_error: 180.9065 - val_loss: 35216.9531 - val_root_mean_squared_error: 187.6618 - 506ms/epoch - 2ms/step
# Epoch 161/1000
# 250/250 - 1s - loss: 32673.8320 - root_mean_squared_error: 180.7590 - val_loss: 35278.1289 - val_root_mean_squared_error: 187.8247 - 554ms/epoch - 2ms/step
# Epoch 162/1000
# 250/250 - 1s - loss: 32662.3008 - root_mean_squared_error: 180.7271 - val_loss: 35660.5547 - val_root_mean_squared_error: 188.8400 - 555ms/epoch - 2ms/step
# Epoch 163/1000
# 250/250 - 1s - loss: 32686.1797 - root_mean_squared_error: 180.7932 - val_loss: 35723.5430 - val_root_mean_squared_error: 189.0067 - 555ms/epoch - 2ms/step
# Epoch 164/1000
# 250/250 - 1s - loss: 32725.6602 - root_mean_squared_error: 180.9023 - val_loss: 35363.1367 - val_root_mean_squared_error: 188.0509 - 671ms/epoch - 3ms/step
# Epoch 165/1000
# Restoring model weights from the end of the best epoch: 160.
# 250/250 - 1s - loss: 32669.5801 - root_mean_squared_error: 180.7473 - val_loss: 35244.4336 - val_root_mean_squared_error: 187.7350 - 778ms/epoch - 3ms/step
# Epoch 165: early stopping

# %%
# Predict
pred = model.predict(x_val)

# Measure MSE error
score = metrics.mean_squared_error(pred,y_val)
print("Final score (MSE): {}".format(score))

# Measure RMSE error
score = np.sqrt(metrics.mean_squared_error(pred,y_val))
print("Final score (RMSE): {}".format(score))
# Out:
# 63/63 [==============================] - 0s 1ms/step
# Final score (MSE): 35216.95025566725
# Final score (RMSE): 187.66179753926278

# %%
# Generate dummies
df_submit = pd.concat([df_submit, pd.get_dummies(df_submit['shape'])],axis=1)

# Standardize ranges
df_submit['height'] = zscore(df_submit['height'])
df_submit['width'] = zscore(df_submit['width'])
df_submit['depth'] = zscore(df_submit['depth'])
df_submit['quality'] = zscore(df_submit['quality'])

# Convert to numpy
x_submit = df_submit[x_columns].values

# %%
# Predict
pred_submit = pd.DataFrame(model.predict(x_submit), columns=['cost'])
df_submit = pd.concat([df_submit['id'], pred_submit], axis=1)
# Out:
# 63/63 [==============================] - 0s 1ms/step

# %%
submit(source_file=file,data=[df_submit],key=key,no=8)
# Out:
# Success: Submitted Assignment 8 for h.kuo:
# You have submitted this assignment 2 times. (this is fine)
# Note: The mean difference 7.241759098499983 for column 'cost' is acceptable and is less than the maximum allowed value of '50.0' for this assignment.
# No warnings or errors (only notes), you will probably do well, but no guarantee. :-)
